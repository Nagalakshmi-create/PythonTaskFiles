# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagalakshmi-create/PythonTaskFiles/blob/master/yolov3_mask_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/yolov3_mask_dataset'
# Out:
# backup	darknet  mask_data_yolov3  weights

# %%
#!unzip '/content/drive/MyDrive/yolov3_mask_dataset/mask_data_yolov3.zip' -d '/content/drive/MyDrive/yolov3_mask_dataset/'
# Out:
# Archive:  /content/drive/MyDrive/yolo_custom_model_training/custom_dataset.zip
#    creating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/maksssksksss189.png
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_5.jpg
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_12.jpg
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_13.jpg
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_15.jpg
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_17.jpg
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_18.jpg
#   inflating: /content/drive/MyDrive/yolo_custom_model_training/custom_dataset/image_20.jpg
# ...

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolov3_mask_dataset/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolo_custom_model_training/darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.02 MiB | 5.75 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd /content/drive/MyDrive/yolov3_mask_dataset/darknet
# Out:
# /content/drive/MyDrive/yolov3_mask_dataset/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
#!make
# Out:
# chmod +x *.sh

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/drive/MyDrive/yolov3_mask_dataset/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ...

# %%
# %cd /content/drive/MyDrive/yolov3_mask_dataset
# Out:
# /content/drive/MyDrive/yolov3_mask_dataset

# %%
# !python mask_data_yolov3/creating-files-data-and-name.py

# %%
# !python mask_data_yolov3/creating-train-and-test-txt-files.py

# %%
# !ls
# Out:
# backup	darknet  mask_data_yolov3  weights

# %%
# %cd /content/drive/MyDrive/yolov3_mask_dataset/darknet
# Out:
# /content/drive/MyDrive/yolov3_mask_dataset/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# %cd /content/drive/MyDrive/yolov3_mask_dataset
# Out:
# /content/drive/MyDrive/yolov3_mask_dataset

# %%
# !darknet/darknet detector train mask_data_yolov3/labelled_data.data darknet/cfg/yolov3_custom.cfg weights/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.863247), count: 2, class_loss = 0.294259, iou_loss = 0.049105, total_loss = 0.343363
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.273675, iou_loss = 0.000000, total_loss = 0.273675
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 194546, rewritten_bbox = 0.002056 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.668800), count: 1, class_loss = 0.775564, iou_loss = 0.124499, total_loss = 0.900063
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.706489), count: 4, class_loss = 0.989483, iou_loss = 0.700485, total_loss = 1.689968
# ...
