# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagalakshmi-create/PythonTaskFiles/blob/master/emotion_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
img = cv2.imread('/home/neosoft/Documents/emotion_imgs/download.jpeg')
plt.imshow(img[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img,actions=['emotion'])
#print(result)
result['dominant_emotion']
# Out:
# 'surprise'
